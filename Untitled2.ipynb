# %%
import numpy as np

def gauss(A, b):
    '''
    Solves the system of linear equations given by Ax = b using gaussian elimination.

            Parameters:
                    A(np.array, 1d): Coefficient matrix
                    b(np.array, 1d): Constant terms

            Returns:
                    x(np.array, 1d): Solution of the system
    '''

    (n, m) = A.shape
    Aaug = np.zeros((n, n+1))
    Aaug[0:n, 0:n] = A
    Aaug[:, n] = b

    for k in range(n-1):
        for i in range(k+1, n):
            m = -Aaug[i, k]/Aaug[k, k]
            Aaug[i, :] = Aaug[i, :]+m*Aaug[k, :]

    x = np.zeros(n)
    for i in range(n-1, -1, -1):
        x[i] = (Aaug[i, n]-np.dot(Aaug[i, 0:n], x))/Aaug[i, i]
    return x

def gauss_seidel(A, b, x0, errMax=0.0001, itMax=100):
    '''
    Solves the system of linear equations given by Ax = b using the Gauss-Seidel method.

            Parameters:
                    A(np.array, 1d): Coefficient matrix
                    b(np.array, 1d): Constant terms
                    x0(np.array, 1d): Starting point
                    errMax(float): Maximum allowed error
                    itMax(int): Maximum number of iterations

            Returns:
                    x(np.array, 1d): Solution of the system
    '''
    n, _ = A.shape
    x1 = np.zeros(n)
    for _ in range(itMax):
        for i in range(n):
            s = 0
            for j in range(i):
                s = s + A[i, j] * x1[j]
            for j in range(i + 1,n):
                s = s + A[i, j] * x0[j]
            x1[i] = (b[i] - s)/A[i, i]
        if np.linalg.norm(x0 - x1, np.Inf) < errMax:
            break
        x0 = x1.copy()
    return x1

def jacobi(A, b, x0, errMax=0.0001, itMax=100):
    '''
    Solves the system of linear equations given by Ax = b using the jacobi method.

            Parameters:
                    A(np.array, 1d): Coefficient matrix
                    b(np.array, 1d): Constant terms
                    x0(np.array, 1d): Starting point
                    errMax(float): Maximum allowed error
                    itMax(int): Maximum number of iterations

            Returns:
                    x(np.array, 1d): Solution of the system
    '''
    n, _ = A.shape
    x1 = np.zeros(n)
    for _ in range(itMax):
        for i in range(n):
            s = 0
            for j in range(n):
                if i != j:
                    s = s + A[i, j] * x0[j]
                x1[i] = (b[i] - s)/A[i, i]
        if np.linalg.norm(x0 - x1, np.Inf) < errMax:
            break
        x0 = x1.copy()
    return x1

def zeroBisection(f, a, b, errMax=0.0001, itMax=100):
    '''
    Finds the zero of a function using the Bisection method

            Parameters:
                    f(function): Target function
                    a(np.array, 1d): Left boundry
                    b(np.array, 1d): Right boundry
                    errMax(float): Maximum allowed error
                    itMax(int): Maximum number of iterations

            Returns:
                    x(np.array, 1d): x where f(x)==0
                    it: number of performed iterations
    '''
    for it in range(itMax):
        zero = (a + b)/2
        fZero = f(zero)

        if abs(fZero) < errMax or abs(b - a) < errMax:
            return zero, it + 1
        
        if f(a)*fZero < 0:
            b = zero
        else:
            a = zero

    return zero, it + 1

def zeroFalsePosition(f, a, b, errMax=0.0001, itMax=100):
    '''
    Finds the zero of a function using the FalsePosition method

            Parameters:
                    f(function): Target function
                    a(np.array, 1d): Left boundry
                    b(np.array, 1d): Right boundry
                    errMax(float): Maximum allowed error
                    itMax(int): Maximum number of iterations

            Returns:
                    x(np.array, 1d): x where f(x)==0
                    it: number of performed iterations
    '''
    for it in range(itMax):
        fA = f(a)
        fB = f(b)
        zero = b - fB*(b - a)/(fB - fA)

        fZero = f(zero)

        if abs(fZero) < errMax or abs(b - a) < errMax:
            return zero, it

        if fA*fZero < 0:
            b = zero
        else:
            a = zero

    return zero, it

def zeroNewton(f, df, x0, errMax=0.0001, itMax=100):
    '''
    Finds the zero of a function using the Newton method

            Parameters:
                    f(function): Target function
                    df(function): Derivative function
                    x0(np.array, 1d): Starting point
                    errMax(float): Maximum allowed error
                    itMax(int): Maximum number of iterations

            Returns:
                    x(np.array, 1d): x where f(x)==0
                    it: Number of performed iterations
    '''

    for it in range(itMax):
        zero = x0 - f(x0)/df(x0)

        fZero = f(zero)
        if abs(fZero) < errMax:
            return zero, it + 1
        
        x0 = zero

    return zero, it + 1

def zeroSecant(f, a, b, errMax=0.0001, itMax=100):
    '''
    Finds the zero of a function using the Secant method

            Parameters:
                    f(function): Target function
                    a(np.array, 1d): Left boundry
                    b(np.array, 1d): Right boundry
                    errMax(float): Maximum allowed error
                    itMax(int): Maximum number of iterations

            Returns:
                    x(np.array, 1d): x where f(x)==0
                    it: number of performed iterations
    '''
    for i in range(itMax):
        fA = f(a)
        fB = f(b)
        zero = b - fB*(b - a)/(fB - fA)

        fZero = f(zero)

        if abs(fZero) < errMax:
            return zero, i + 1
        
        a = b
        b = zero

    return zero, i + 1


def lagrange_interpolation(x, fX):
    '''
    Finds the Lagrange polynomial for given points

            Parameters:
                    x(np.array, 1d): Points on x axis
                    fX(np.array, 1d): Points on y axis

            Returns:
                    p(np.array, 1d): Lagrange polynomial coefficients such that 
                                     L = p[0]*x**(N-1) + p[1]*x**(N-2) + ... + p[N-2]*x + p[N-1]
    '''
    order = x.size

    p = 0

    for itFX in range(order):
        lNumer = 1
        lDenom = 1

        for itX in range(itFX):
            lNumer = np.convolve(lNumer, np.array([1, -x[itX]]))
            lDenom = lDenom * (x[itFX] - x[itX])
        
        for itX in range(itFX+1, order):
            lNumer = np.convolve(lNumer, np.array([1, -x[itX]]))
            lDenom = lDenom*(x[itFX] - x[itX])

        p = p + lNumer/lDenom*fX[itFX]

    return p


def least_squares_regression(x, fX, order):
    '''
    Performs least-squares regression with polynomial of given order

            Parameters:
                    x(np.array, 1d): Points on x axis
                    fX(np.array, 1d): Points on y axis
                    order(int): Polynomial order

            Returns:
                    p(np.array, 1d): Polynomial coefficients of the least-squares solution such that 
                                     R = p[0]*x**(N-1) + p[1]*x**(N-2) + ... + p[N-2]*x + p[N-1]
    '''
    n = x.size
    m = min(order+1, n)
    A = np.zeros((n, m))

    for it in range(m):
        A[:, it] = x**(it)
    
    a = np.linalg.solve(np.matmul(A.T, A), np.matmul(A.T, fX))

    p = a[::-1]
    return p

# %%
x2= 1.7
x1=x2-1.2
p = np.array([[1. , x1 , x1**2, x1**3],
              [1. , (x1*4-x2*2) , (x1*4-x2*2)**2, (x1*4-x2*2)**3],
              [1. , 2*x1 , (2*x1)**2, (2*x1)**3],
              [1. , x2 , x2**2, x2**3]])
a = np.zeros(4)
b = np.array([5.625, -0.512, x2+14.3, 44.469])
a=gauss(p,b)

trebaDaJe1 = np.sqrt(a[0]) - (2/5*a[1]) - a[2] + a[3]**2
print(trebaDaJe1)
# Out:
# 1.0000000000000195

# %%
import matplotlib.pyplot as plt
f = lambda x: np.sin(x**2 - 2)
g = lambda x : np.cos(x) * x
a = -3.
b = 1.
x = np.linspace(a,b,1000)

#A
plt.plot([a,b], [0,0], 'black')
fx = f(x)
gx = g(x)
plt.plot(x, fx, 'blue')
plt.plot(x, gx, 'green')

#B
zero, it = zeroFalsePosition(f, a, -2.5, 10**-5, 100)
fzero = f(zero)
plt.scatter(zero, fzero, c='black')
aa = zero+0.1
zero, it = zeroFalsePosition(f, aa, -1.5, 10**-5, 100)
fzero = f(zero)
plt.scatter(zero, fzero, c='black')
aaa = zero+0.1
zero, it = zeroFalsePosition(f, aaa, b, 10**-5, 100)
fzero = f(zero)
plt.scatter(zero, fzero, c='black')


# C
fraz = lambda x: f(x) - g(x)
presek, it = zeroFalsePosition(fraz,a , -2., 10**-5, 100)
fpresek= f(presek)
plt.scatter(presek, fpresek, c='gray')
presek, it = zeroFalsePosition(fraz, -2. , b, 10**-5, 100)
fpresek= f(presek)
plt.scatter(presek, fpresek, c='gray')

#D

import sympy as sym
x_sym = sym.Symbol('x')
df_sym = sym.diff(sym.sin(x_sym**2-2) )
df = sym.lambdify(x_sym, df_sym, 'numpy')

maxx, it = zeroFalsePosition(df, a, -1.8, 10**-5, 100)
print('max od f je =', maxx)
fMax=f(maxx)
plt.scatter(maxx,fMax, c='purple')

dg = lambda x: np.cos(x) - x * np.sin(x)
dgx = dg(x)
minn, it = zeroFalsePosition(dg, a, 0., 10**-5, 100)
print('min od g je =', minn)
gmin= g(minn)
plt.scatter(minn,gmin, c='orange')

#E

funx = lambda x: x*0 + np.pi/6
funxx = funx(x)
plt.plot(x, funxx, 'cyan')
fr = lambda x: f(x) - funx(x)
prsk, it = zeroFalsePosition(fr,a , -2.7, 10**-5, 100)
print(prsk)
fprsk= f(prsk)
plt.scatter(prsk, fprsk, c='tomato')
prsk, it = zeroFalsePosition(fr, -2.5 , -2., 10**-5, 100)
print(prsk)
fprsk= f(prsk)
plt.scatter(prsk, fprsk, c='tomato')
prsk, it = zeroFalsePosition(fr, -2. , b, 10**-5, 100)
print(prsk)
fprsk= f(prsk)
plt.scatter(prsk, fprsk, c='tomato')

fr2 = lambda x: g(x) - funx(x)
prsk, it = zeroFalsePosition(fr2,a , 0., 10**-5, 100)
print(prsk)
fprsk= g(prsk)
plt.scatter(prsk, fprsk, c='pink')
prsk, it = zeroFalsePosition(fr2,0. , b, 10**-5, 100)
print(prsk)
fprsk= g(prsk)
plt.scatter(prsk, fprsk, c='pink')
# Out:
# max od f je = -1.8896550365903255
# min od g je = -0.8603331388905042
# -2.972247465525193
# -2.14254817930676
# -1.5972084628919396
# -1.8566819443536011
# 0.6658108349377244

# %%
def fz4a(A, B):
    m, n = A.shape
    k, k2 = B.shape
    z = np.zeros((m-k+1,n-k+1))
    zx, zy = z.shape
    if k!=k2:
        return('B mora biti kvadratna')
    if k>m or k>n:
        return('ne')
    
    for y in range(zy):
        for x in range(zx):
            for q in range(k):
                for w in range(k):
                    z[x,y]=z[x,y]+(B[w,q]*A[w+x,q+y])
                    
    return z

# %%
A = np.array([[1, 2, 3],
              [0, 3, 7],
              [4, 1, 2]])
B= np.array([[4,3],
            [2,1]])
c=fz4a(A,B)
c
# Out:
# array([[13., 30.],
#        [18., 37.]])

# %%
A = np.array([
[1, 2, 3, 1, 1],
[0, 3, 0, 1, 3],
[0, 3, 0, 1, 4],
[0, 3, 2, 1, 2],
[4, 1, 2, 1, 4]
])
B = np.array([
[0, 3, 1],
[0, 2, 2],
[2, 1, 1]
])
c = fz4a(A,B)
c
fz4b(A)
# Out:
# True

# %%
def fz4b(A):
    m, n= A.shape
    if m<2 or n<2:
        return('ne')
   
    for y in range(n-2):
        for x in range(m-2):
            z = A[y,x:x+3]
            q = A[y:y+3,x]
            w = A[x, y]
            w = np.append(w,A[x+1,y+1])
            w = np.append(w,A[x+2,y+2])
            if np.all(z==z[0]):
                return True
            if np.all(q==q[0]):
                return True
            if np.all(w==w[0]):
                return True
    for y in range(n-1, 1, -1):
        for x in range(m-1, 1,-1):
            z = A[y, x-2:x+1]
            q = A[y-2:y+1,x]
            if np.all(z==z[0]):
                return True
            if np.all(q==q[0]):
                return True
    for y in range(n-1, 1, -1):
        for x in range(m-2):
            w = A[x, y]
            w = np.append(w,A[x+1,y-1])
            w = np.append(w,A[x+2,y-2])
            if np.all(w==w[0]):
                return True
            
            
            
    return False

# %%
f = lambda x: np.sqrt(2) * np.sin(2*x) + np.cos(-x/3)
x= np.linspace(np.pi/2*-1, np.pi*4/3,1000)
#A
fx=f(x)
plt.plot(x, fx, 'blue')
#B
points = np.linspace(np.pi/2*-1, np.pi*4/3, 5)
f_points = f(points)
plt.scatter(points, f_points, c='g')
p = lagrange_interpolation(points, f_points)
#print(p)
print('p(x) =', ' '.join('{0:+5.1f}x^{1:1d}'.format(coef[1], p.shape[0]-coef[0]-1) for coef in enumerate(p)))
pX = np.polyval(p,x)
plt.plot(x, pX, 'red')

xpoints = np.linspace(np.pi/2*-1, np.pi*4/3, 4)
f_xpoints = f(xpoints)
xx = least_squares_regression(xpoints, f_xpoints, 3)
#print('p(x) =', ' '.join('{0:+5.1f}x^{1:1d}'.format(coef[1], xx.shape[0]-coef[0]-1) for coef in enumerate(xx)))
xpoints = np.linspace(np.pi/2*-1, np.pi*4/3, 100)
XXX = np.polyval(xx, x)
plt.plot(xpoints,XXX, 'brown')

fraz = lambda x: np.polyval(p, x) - np.polyval(xx, x)
presek, it = zeroFalsePosition(fraz,np.pi/2*-1 , -1., 10**-5, 100)
print('x1 = ' ,presek)
presek1 = np.polyval(p, presek)
plt.scatter(presek, presek1, c= 'black')

presek, it = zeroFalsePosition(fraz,-1. , 1., 10**-5, 100)
print('x2 = ' ,presek)
presek1 = np.polyval(p, presek)
plt.scatter(presek, presek1, c= 'black')

presek, it = zeroFalsePosition(fraz,1. , 3., 10**-5, 100)
print('x3 = ' ,presek)
presek1 = np.polyval(p, presek)
plt.scatter(presek, presek1, c= 'black')

presek, it = zeroFalsePosition(fraz,3. ,np.pi*4/3 , 10**-5, 100)
print('x3 = ' ,presek)
presek1 = np.polyval(p, presek)
plt.scatter(presek, presek1, c= 'black')
# Out:
# p(x) =  +0.1x^4  -0.5x^3  -0.1x^2  +1.4x^1  +0.8x^0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-92ed35b61b00> in <module>
#      16 xpoints = np.linspace(np.pi/2*-1, np.pi*4/3, 4)
#      17 f_xpoints = f(xpoints)
# ---> 18 xx = least_squares_regression(xpoints, f_xpoints, 3)
#      19 #print('p(x) =', ' '.join('{0:+5.1f}x^{1:1d}'.format(coef[1], xx.shape[0]-coef[0]-1) for coef in enumerate(xx)))
#      20 xpoints = np.linspace(np.pi/2*-1, np.pi*4/3, 100)
#
# <ipython-input-39-eba088199128> in least_squares_regression(x, fX, order)
#     251     '''
#     252     n = x.size
# --> 253     m = min(order+1, n)
#     254     A = np.zeros((n, m))
#     255
#
# TypeError: 'numpy.float64' object is not callable

# %%
f = lambda x: np.sqrt(2) * np.sin(2*x) + np.cos(-x/3)
x= np.linspace(np.pi/2*-1, np.pi*4/3,1000)
#A
fx=f(x)
plt.plot(x, fx, 'blue')
#B
points = np.linspace(np.pi/2*-1, np.pi*4/3, 5)
f_points = f(points)
plt.scatter(points, f_points, c='g')
p = lagrange_interpolation(points, f_points)
#print('p(x) =', ' '.join('{0:+5.1f}x^{1:1d}'.format(coef[1], p.shape[0]-coef[0]-1) for coef in enumerate(p)))
pX = np.polyval(p,x)
plt.plot(x, pX, 'red')

x = np.linspace(np.pi/2*-1, np.pi*4/3, 100)
fX = f(x)
xx = least_squares_regression(x, fX, 3)
#print('p(x) =', ' '.join('{0:+5.1f}x^{1:1d}'.format(coef[1], xx.shape[0]-coef[0]-1) for coef in enumerate(xx)))
xpoints = np.linspace(np.pi/2*-1, np.pi*4/3, 100)
XXX = np.polyval(xx, x)
plt.plot(xpoints,XXX, 'brown')

# %%
min
# Out:
# -0.8603331388905042
